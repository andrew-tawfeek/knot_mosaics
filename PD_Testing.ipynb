# %%
load("wild_mosaics.py")

# %%
random_mosaic(dimension = 10).matrix()
# Out:
# [ 2  1  0  2  1  0  2  1  2  1]
# [ 6  3  1  3  9  1  3 10  7  4]
# [ 6  0  6  0  6  6  2 10  9  1]
# [ 3  5  8  5  4  3  9  4  6  6]
# [ 0  0  3  5  1  0  3  1  6  6]
# [ 0  2  5  5  8  1  0  6  6  6]
# [ 0  3  1  2  9 10  1  6  3  4]
# [ 2  5 10 10  9  7 10  7  1  0]
# [ 6  0  6  6  3  8  8  7  9  1]
# [ 3  5  4  3  5  4  3  4  3  4]

# %%
M.zoom().show(10)
# Out:
# Graphics Array of size 12 x 12

# %%
M_zoomed = M.zoom(); M.findCrossings()
# Out:
# [(1, 1), (1, 2), (2, 1), (2, 2)]

# %%
M_zoomed.strandOf((1,1),'up')
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# /tmp/ipykernel_677/31840614.py in <module>
# ----> 1 M_zoomed.strandOf((Integer(1),Integer(1)),'up')
#
# /mnt/c/Users/tawfe/Documents/GitHub/knot_mosaics/wild_mosaics.py in strandOf(self, crossing, direction)
#     268         # Orientation at crossign defaults to 'up' unless otherwise indicated.
#     269         crossings = self.findCrossings()
# --> 270         assert crossing in crossings
#     271
#     272         initial = crossing
#
# AssertionError:

# %%
M.zoom(onlyUpDown = True).show(10)
# Out:
# Graphics Array of size 12 x 12

# %%
M = M.zoom(onlyUpDown = True); M.size
# Out:
# 108

# %%
M.matrix()
# Out:
# 108 x 108 dense matrix over Integer Ring (use the '.str()' method to see the entries)

# %%
M.findCrossings()
# Out:
# [(40, 40), (40, 67), (67, 40), (67, 67)]

# %%
walk = M.strandOf((40,40), 'up')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_1215/1851797342.py in <module>
# ----> 1 walk = M.strandOf((Integer(40),Integer(40)), 'up')
#
# /mnt/c/Users/tawfe/Documents/GitHub/knot_mosaics/wild_mosaics.py in strandOf(self, crossing, direction)
#     260
#     261         while position != initial:
# --> 262             strandPath += self.walk(position, direction, pathList = True)[1:] # Drops off repeated start (time = 0)
#     263             position, direction = self.walk(position, direction, tangent = True)
#     264             if position == initial:  # This prevent stopping the while loop if initial crossing approached orthogonally
#
# /mnt/c/Users/tawfe/Documents/GitHub/knot_mosaics/wild_mosaics.py in walk(self, crossing, direction, pathList, tangent)
#     218         # Continue walking until reaching another crossing
#     219         while len(Tile(M[pos_x][pos_y]).connectionDirections) == 2: # If it's a two way street, keep going
# --> 220             accessible_coords = self.shift(pos_x,pos_y)
#     221             accessible_coords.remove((prev_x, prev_y)) # only one possibility after this
#     222             (prev_x, prev_y) = (pos_x, pos_y)
#
# /mnt/c/Users/tawfe/Documents/GitHub/knot_mosaics/wild_mosaics.py in shift(self, i, j, dictionary)
#     176     def shift(self,i,j, dictionary = False):
#     177         # Setting 'dictionary = True' allows a dictionary return of tile directions
# --> 178         assert self.isSuitablyConnected() == True # prevents indexing issues
#     179         M = self.matrixRepresentation
#     180         directions = Tile(M[i][j]).connectionDirections
#
# /mnt/c/Users/tawfe/Documents/GitHub/knot_mosaics/wild_mosaics.py in isSuitablyConnected(self)
#     123         for i in range(self.size):
#     124             for j in range(self.size):
# --> 125                 if Tile(M[i][j]).isGoing('up'):
#     126                     if i == 0:
#     127                         return False
#
# /usr/lib/python3/dist-packages/sage/matrix/matrix0.pyx in sage.matrix.matrix0.Matrix.__getitem__ (build/cythonized/sage/matrix/matrix0.c:8445)()
#    1033             if row < 0 or row >= nrows:
#    1034                 raise IndexError("matrix index out of range")
# -> 1035             r = self.row(row)
#    1036
#    1037         r.set_immutable()
#
# /usr/lib/python3/dist-packages/sage/matrix/matrix_integer_dense.pyx in sage.matrix.matrix_integer_dense.Matrix_integer_dense.row (build/cythonized/sage/matrix/matrix_integer_dense.cpp:43941)()
#    5196         cdef Py_ssize_t j
#    5197         parent = self._row_ambient_module()
# -> 5198         cdef Vector_integer_dense v = parent.zero_vector()
#    5199         for j in range(self._ncols):
#    5200             fmpz_get_mpz(v._entries[j], fmpz_mat_entry(self._matrix, i, j))
#
# /usr/lib/python3/dist-packages/sage/modules/free_module.py in zero_vector(self)
#    2511         # it is used by __call__ to make a new copy of the 0 element.
#    2512
# -> 2513         return self.element_class(self, 0)
#    2514
#    2515     @cached_method
#
# /usr/lib/python3/dist-packages/sage/modules/vector_integer_dense.pyx in sage.modules.vector_integer_dense.Vector_integer_dense.__cinit__ (build/cythonized/sage/modules/vector_integer_dense.c:3429)()
#     111             self._degree = 0
#     112             return
# --> 113         self._init(parent.degree(), <Parent?>parent)
#     114
#     115     def __init__(self, parent, x, coerce=True, copy=True):
#
# /usr/lib/python3/dist-packages/sage/modules/vector_integer_dense.pyx in sage.modules.vector_integer_dense.Vector_integer_dense._init (build/cythonized/sage/modules/vector_integer_dense.c:3141)()
#      97         cdef mpz_t* entries = <mpz_t*>check_allocarray(degree, sizeof(mpz_t))
#      98         cdef Py_ssize_t i
# ---> 99         sig_on()
#     100         for i in range(degree):
#     101             mpz_init(entries[i])
#
# KeyboardInterrupt:

# %%
for x in M.findCrossings():
    print(x in walk)
    print(walk.index(x))
# Out:
# True
# True
# True

# %%
def planarDiagramCode(mosaic):
    M = mosaic.zoom(onlyUpDown = True).zoom() # first zoom removes 9 tiles (replaced by 10), next removes 7,8 tiles
    # the double zoom above is what slows down things most, best to adjust strandOf function
    # to deal with the 7,8 tiles -- then one zoom is sufficient (if entering 7 from above, go right, etc. -- just do cases)
    crossing_list = M.findCrossings()
    walk = M.strandOf(crossing_list[0], 'up')
    pass

# %%
L = Link([[3,4,2,1], [20,7,1,9], [5,3,7,6], [4,5,6,18],

           [17,18,8,19], [9,14,11,10], [10,11,13,12],

           [12,13,15,19], [8,15,14,16], [16,2,17,20]])

# %%
L.plot()
# Out:
# Graphics object consisting of 32 graphics primitives

# %%
L.is_knot()
# Out:
# False

# %%
L.number_of_components()
# Out:
# 2
