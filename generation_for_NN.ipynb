# %%
load("wild_mosaics.py") #sage -n jupyter --no-browser

# %%
for i in range(0,10):
    mosaic = list(random_mosaic(dimension = 5).matrix())
    print(str((mosaic ,1))+",")
for i in range(0,10):
    mosaic = list(random_mosaic(dimension = 5, suitably_connected=False).matrix())
    print(str((mosaic ,0))+",")
# Out:
# ([(0, 2, 1, 0, 0), (2, 8, 10, 1, 0), (3, 4, 3, 9, 1), (2, 1, 0, 3, 4), (3, 4, 0, 0, 0)], 1),
# ([(2, 5, 1, 2, 1), (6, 2, 9, 4, 6), (3, 10, 4, 2, 4), (2, 10, 5, 9, 1), (3, 4, 0, 3, 4)], 1),
# ([(0, 2, 1, 0, 0), (0, 6, 3, 1, 0), (2, 7, 5, 4, 0), (6, 3, 1, 0, 0), (3, 5, 4, 0, 0)], 1),
# ([(2, 5, 1, 0, 0), (6, 2, 10, 1, 0), (3, 10, 7, 10, 1), (2, 8, 8, 10, 4), (3, 4, 3, 4, 0)], 1),
# ([(0, 2, 1, 2, 1), (0, 3, 7, 4, 6), (2, 5, 8, 5, 4), (3, 5, 7, 5, 1), (0, 0, 3, 5, 4)], 1),
# ([(2, 1, 2, 5, 1), (6, 6, 3, 1, 6), (6, 6, 2, 8, 4), (6, 6, 6, 6, 0), (3, 4, 3, 4, 0)], 1),
# ([(2, 5, 5, 5, 1), (3, 5, 1, 0, 6), (2, 1, 6, 2, 4), (6, 3, 8, 7, 1), (3, 5, 4, 3, 4)], 1),
# ([(2, 5, 5, 5, 1), (3, 1, 0, 2, 4), (0, 6, 0, 3, 1), (2, 7, 5, 1, 6), (3, 4, 0, 3, 4)], 1),
# ([(2, 1, 0, 0, 0), (3, 10, 5, 5, 1), (2, 8, 1, 0, 6), (6, 3, 4, 0, 6), (3, 5, 5, 5, 4)], 1),
# ([(2, 1, 0, 0, 0), (6, 6, 2, 5, 1), (6, 3, 7, 5, 4), (6, 2, 4, 0, 0), (3, 4, 0, 0, 0)], 1),
# ([(2, 3, 2, 10, 5), (6, 6, 3, 0, 9), (9, 1, 7, 5, 6), (0, 5, 2, 0, 1), (1, 5, 3, 10, 2)], 0),
# ([(0, 2, 3, 6, 0), (9, 6, 6, 9, 3), (5, 2, 8, 0, 2), (10, 6, 4, 0, 4), (5, 8, 8, 3, 5)], 0),
# ([(8, 4, 8, 9, 10), (2, 7, 7, 0, 10), (0, 10, 1, 0, 9), (5, 9, 0, 6, 8), (1, 5, 7, 5, 5)], 0),
# ([(9, 0, 6, 9, 5), (8, 4, 1, 4, 8), (0, 10, 2, 7, 4), (4, 6, 4, 8, 4), (2, 5, 10, 0, 7)], 0),
# ([(6, 6, 2, 5, 10), (2, 7, 3, 7, 3), (9, 4, 8, 6, 8), (2, 9, 7, 5, 3), (9, 8, 2, 10, 2)], 0),
# ([(8, 2, 8, 6, 3), (8, 4, 8, 6, 6), (7, 10, 0, 2, 5), (2, 4, 7, 4, 9), (7, 2, 10, 0, 6)], 0),
# ([(3, 1, 1, 0, 7), (4, 3, 9, 10, 5), (1, 4, 9, 8, 5), (8, 9, 3, 3, 0), (10, 3, 6, 7, 10)], 0),
# ([(4, 9, 1, 8, 1), (0, 1, 2, 10, 0), (4, 1, 4, 8, 9), (0, 10, 8, 2, 9), (6, 8, 5, 10, 4)], 0),
# ([(9, 8, 10, 0, 7), (2, 1, 8, 7, 8), (6, 7, 8, 7, 8), (0, 5, 8, 5, 0), (7, 9, 10, 2, 10)], 0),
# ([(4, 5, 0, 5, 7), (0, 4, 7, 7, 0), (1, 3, 3, 1, 1), (10, 0, 3, 4, 1), (9, 1, 9, 3, 0)], 0),

# %%
samples = 300

data_pairs = [(list(random_mosaic(dimension = 5).matrix()) ,1) for i in range(0,samples)] + [(list(random_mosaic(dimension = 5, suitably_connected=False).matrix()) ,0) for i in range(0,samples)]

with open('data.py', 'w') as f:
    f.write('data_pairs = ' + str(data))
