# %%
load("wild_mosaics.py")

# this function assumes the mosaic is single component and nonempty
# returns true if the mosaic is the unknot, false otherwise
def jones_unknot(mosaic):

    if mosaic.numCrossings() > 22:
        raise Exception("Jones can not reliably detect knottedness. Number of crossings: ", mosaic.numCrossings())

    K = Link(orientedGaussCode(mosaic))
    
    if K.jones_polynomial(algorithm = 'statesum') == 1:
        return true
    else:
        return false

# %%
T = random_mosaic(dimension = 10, num_components = 1)
print(jones_unknot(T))
T.show(10)
# Out:
# True
# Graphics Array of size 10 x 10

# %%
T = random_mosaic(dimension = 12, num_components = 1)
print(jones_unknot(T))
T.show(12)
# Out:
# False
# Graphics Array of size 12 x 12

# %%
T = random_mosaic(dimension = 15, num_components = 1)
print(jones_unknot(T))
T.show(15)
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[16], line 2
#       1 T = random_mosaic(dimension = Integer(15), num_components = Integer(1))
# ----> 2 print(jones_unknot(T))
#       3 T.show(Integer(15))
#
# Cell In[14], line 8, in jones_unknot(mosaic)
#       5 def jones_unknot(mosaic):
#       7     if mosaic.numCrossings() > Integer(22):
# ----> 8         raise Exception("Jones can not reliably detect knottedness. Number of crossings: ", mosaic.numCrossings())
#      10     K = Link(orientedGaussCode(mosaic))
#      12     if K.jones_polynomial(algorithm = 'statesum') == Integer(1):
#
# Exception: ('Jones can not reliably detect knottedness. Number of crossings: ', 30)
